# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import OneHotEncoder,LabelEncoder
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('PlayTennis.csv')
X = df.drop(columns='Play Tennis')
Y = df['Play Tennis']

ohe = OneHotEncoder(sparse_output=False)
X_encoded = ohe.fit_transform(X)
le = LabelEncoder()
Y_encoded = le.fit_transform(Y)

X_train,X_test,Y_trian,Y_test = train_test_split(X_encoded,Y_encoded,train_size=0.3,random_state=42)

model = DecisionTreeClassifier()
model.fit(X_train,Y_trian)
y_pred = model.predict(X_test)
print(f"accuracy = {accuracy_score(Y_test,y_pred)}")
# Out:
# accuracy = 0.6

# %%
outlook = input("Enter Outlook (Sunny, Overcast, Rain): ")
temperature = input("Enter Temperature (Hot, Mild, Cool): ")
humidity = input("Enter Humidity (High, Normal): ")
wind = input("Enter Wind (Weak, Strong): ")

user_input = {
    'Outlook': outlook,
    'Temperature': temperature,
    'Humidity': humidity,
    'Wind': wind
}

user_input_df = pd.DataFrame([user_input])
user_input_encoded = ohe.transform(user_input_df)
user_input_encoded
pred = model.predict(user_input_encoded)
pred = le.inverse_transform(pred)
print(pred[0])
# Out:
# No

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
plot_tree(model)
plt.show()
